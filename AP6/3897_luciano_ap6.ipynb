# %% [markdown]
# > Introdução à Ciência dos Dados \
# > Ciência da Computação – UFV/Florestal
#
#
# * **Nome:** Luciano Belo de Alcântara Júnior
# * **Matrícula:**  3897
#
# # Aula Prática 06
# ## Visualização de Dados
#
# **Objetivo:** Entender comandos para explorar dados visualmente por meio de gráficos.
# **Pré-requisitos:** Linguagem de programação Python, estatística básica \
# **Meta:** Ao final da prática, o aluno será capaz de analisar um conjunto de dados visualmente para ajudar na tomada de decisões.
#
# ----

# %%
### NÃO REMOVA ESSA CÉLULA! ####
# !pip --no-cache-dir install --upgrade learntools_dados_ufv

# !wget https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting learntools_dados_ufv
#   Downloading learntools_dados_ufv-1.0.6.tar.gz (25 kB)
# Building wheels for collected packages: learntools-dados-ufv
#   Building wheel for learntools-dados-ufv (setup.py) ... done
#   Created wheel for learntools-dados-ufv: filename=learntools_dados_ufv-1.0.6-py3-none-any.whl size=31952 sha256=fedb57f8edba9611b3ad51c25247ad9c4b88945138c473a1fe9afa209ad0ad59
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6i6omnlr/wheels/97/08/e3/310ea4cb59a4a083f84ed093cfe9ccc2ca9fb1819e40964a02
# Successfully built learntools-dados-ufv
# Installing collected packages: learntools-dados-ufv
# Successfully installed learntools-dados-ufv-1.0.6
# --2022-06-09 13:15:40--  https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23715344 (23M) [application/octet-stream]
# Saving to: ‘OnlineRetail.xlsx’
#
# OnlineRetail.xlsx   100%[===================>]  22.62M   149MB/s    in 0.2s
#
# 2022-06-09 13:15:40 (149 MB/s) - ‘OnlineRetail.xlsx’ saved [23715344/23715344]

# %%
#### Não altere essa célula!!! ####
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# # Roteiro

# %% [markdown]
# ## Leitura dos dados
# Veja os dados do arquivo `OnlineRetail.xlsx`.
#
# Note que o arquivo é um Excel. A biblioteca consegue ler e o interpretar da mesma maneira que um CSV, como estamos acostumados.
#
# Note que a função usada é a `read_excel` e não a `read_csv`.
#
# É normal que demore um pouco, pois os arquivos em excel possuem muito mais recursos e dados armazenados do que um simples csv.

# %%
df = pd.read_excel('./OnlineRetail.xlsx')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### Filtrar quantidades e preços unitários negativos

# %%
df = df[(df['Quantity'] > 0) & (df['UnitPrice'] > 0)]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [530104 rows x 8 columns]

# %% [markdown]
# ## Visualizar os dados
#
# ### Gráfico de Pontos (_Scatter Plot_)

# %%
df.plot(kind='scatter', x='UnitPrice', y='Quantity', color='orange', label='Transação')
# Adiciona um rótulo no eixo Y
plt.ylabel('Quantidade')
# Adiciona um rótulo no eixo X
plt.xlabel('Preço Unitário')

plt.show()

# %% [markdown]
# ### Usar escala logarítmica nos dois eixos para melhorar a visualização
# Também vamos gerar um gráfico colorindo e marcando por país

# %%
countries_colors = {
    'Brazil': '#FAA916',
    'USA': '#0FA3B1',
    'Canada': '#BB4430'
}

fig, ax = plt.subplots()
countries_data = list(map(lambda k: (k, df[df['Country'] == k]), countries_colors.keys()))
[ax.scatter(x=d['UnitPrice'], y=d['Quantity'], c=countries_colors[k], label=k) for (k, d) in countries_data]

plt.ylabel('Quantidade')
plt.xlabel('Preço Unitário')
plt.xscale('log')
plt.yscale('log')
ax.legend() # Habilita a legenda das cores
plt.show()

# %% [markdown]
# ### Usar um terceiro atributo para definir o tamanho do marcador
#
# Veja o argumento `s` (de size) da função scatter

# %%
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

fig, ax = plt.subplots()
countries_data = list(map(lambda k: (k, df[df['Country'] == k]), countries_colors.keys()))
[ax.scatter(x=d['UnitPrice'], y=d['Quantity'], c=countries_colors[k], s=d['TotalPrice'], label=k) for (k, d) in countries_data]

plt.ylabel('Quantidade')
plt.xlabel('Preço Unitário')
plt.xscale('log')
plt.yscale('log')
ax.legend() # Habilita a legenda das cores
plt.show()
# Out:
# /var/folders/5k/09d9yfqx7kxbg7vctjt_5q3h0000gn/T/ipykernel_5509/2198645619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# %% [markdown]
# ### Agrupar antes de exibir os gráficos
# Agrupando pelo `InvoiceNo`

# %%
group_invoice = df.groupby('InvoiceNo')

group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')
plt.xlabel('Quantidade')
plt.ylabel('Preço Total')
plt.show()

# %% [markdown]
# ### Gerar o mesmo gráfico anterior na escala logarítmica

# %%
group_invoice = df.groupby('InvoiceNo')

group_invoice.sum().plot.scatter(x='Quantity', y='TotalPrice', c='#EF2D56')
plt.xlabel('Quantidade')
plt.ylabel('Preço Total')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Plotar gráfico de linha para avaliar tendência.
# Agrupar as compras por data e mostrar a quantidade de itens por data da compra.

# %%
group_date = df.groupby('InvoiceDate')
group_date.sum()['Quantity'].plot(c='#EF2D56')
plt.xlabel('Data Compra')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# ### Agrupar por Mês/Ano

# %%
df['MonthYear'] = df['InvoiceDate'].dt.strftime('%m/%Y')

group_month_year = df.groupby('MonthYear')
group_month_year.sum()['Quantity'].plot(c='#EF2D56')
plt.xlabel('Data Compra')
plt.ylabel('Quantidade')
plt.show()
# Out:
# /var/folders/5k/09d9yfqx7kxbg7vctjt_5q3h0000gn/T/ipykernel_5509/1533330249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MonthYear'] = df['InvoiceDate'].dt.strftime('%m/%Y')

# %% [markdown]
# ### Plotar gráfico de barras para mostrar valores para atributos categóricos

# %%
group_invoice.sum().iloc[0:9]['Quantity'].plot(kind='bar', color='#EF2D56')
plt.xlabel('Número da NF')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# ### Plotar Histograma

# %%
group_invoice.sum()['TotalPrice'].plot(kind='hist', color='#EF2D56')
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# ### Filtrar para visualizar melhor a maioria
# O gráfico acima possui uma concentração em valores menores mas possui alguns outliers com preço **muito** superior à maioria. Vamos resolver isso com um filtro.

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56')
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# ### Alterar número de bins para ter mais detalhes

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot(kind='hist', color='#EF2D56', bins=100)
plt.xlabel('Preço Total')
plt.ylabel('Quantidade')
plt.show()

# %% [markdown]
# ### Plotar um BoxPlot

# %%
group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço')
plt.show()

# %% [markdown]
# ### Usar escala logarítmica para ver melhor

# %%
group_invoice.sum()['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Filtrar para valores menores

# %%
group_invoice.sum().loc[group_invoice.sum()['TotalPrice'] < 1000]['TotalPrice'].plot.box(color='#EF2D56')
plt.ylabel('Preço Total')
plt.show()

# %% [markdown]
# ### Plotar boxplots agrupados por país

# %%
df.boxplot('TotalPrice', by='Country', rot=90, figsize=(15, 5), color='purple')
plt.ylabel('Preço Total')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Exercícios

# %% [markdown]
# Execute e não remova a célula abaixo antes de iniciar os exercícios. Faça todas as atividades manipulando a variável `df`.

# %%
# Atribui o dataframe com o estado "original" em uma variável isolada
original_df = pd.read_excel('./OnlineRetail.xlsx')
df = original_df
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## 1. Faça um gráfico de barras mostrando a quantidade total vendida de cada um dos 10 primeiros produtos que aparecem no Dataframe.
# Essa lista não possui correção automática.

# %%
# Resposta da 1.

produts_grouped = df.groupby('StockCode')['Quantity'].sum()
ten_first_produts = produts_grouped[df['StockCode'][:10]]

plt.figure(figsize =(11, 6))
plt.bar(ten_first_produts.index.astype(str), ten_first_produts.values, color = 'orange')
plt.ylabel("# Quantidades")
plt.xlabel("# StockCode dos Produtos")
plt.title("Quantidade total vendida - 10 primeiros produtos")
plt.xticks(ten_first_produts.index.astype(str),rotation='vertical')
plt.subplots_adjust(bottom=0.15)
plt.show()

# %% [markdown]
# ## 2. Faça um Boxplot dos preços unitários dos produtos. Considere somente os 10 produtos mais vendidos.
# Essa lista não possui correção automática.

# %%
# Resposta da 2.

best_selling_products_unit_prices = df["UnitPrice"][produts_grouped.sort_values(ascending = False)[:10]]

plt.figure(figsize =(11, 7))
plt.boxplot(best_selling_products_unit_prices,vert = 0)
plt.xticks(best_selling_products_unit_prices,rotation="vertical")
plt.xlabel("# Preços unitários dos Produtos")
plt.title("Preços unitários - 10 produtos mais vendidos")
plt.show()

# %% [markdown]
# ## 3. Faça um gráfico de linhas mostrando o faturamento (total de preços das vendas) por dia.
# Essa lista não possui correção automática.

# %%
# Resposta da 3.

df_with_total_values = df.assign(TotalValues = df["Quantity"]*df["UnitPrice"])
total_values_per_day = df_with_total_values.groupby('InvoiceDate')['TotalValues'].sum()

plt.figure(figsize =(11, 8))
plt.plot(total_values_per_day, color = "orange")
plt.xlabel("# Dias")
plt.ylabel("# Total de preços das vendas")
plt.title("Total de preços das vendas por dia")
plt.show()

# %% [markdown]
# ## 4. Faça o histograma da média dos preços unitários dos produtos.
# Essa lista não possui correção automática.

# %%
# Resposta da 4.
mean_produts_grouped_unit_prices = df.groupby('StockCode')['UnitPrice'].mean()

plt.figure(figsize =(11, 8))
plt.hist(mean_produts_grouped_unit_prices, density=True, color = "orange")
plt.yscale('log')
plt.xlabel("# Médias dos preços unitários")
plt.ylabel("# StockCode's")
plt.title("Média dos preços unitários dos produtos")
plt.show()

display(mean_produts_grouped_unit_prices)
# Out:
# StockCode
# 10002            1.056849
# 10080            0.376667
# 10120            0.210000
# 10125            0.859681
# 10133            0.645800
#                   ...
# gift_0001_20    15.038000
# gift_0001_30    21.941250
# gift_0001_40    33.566667
# gift_0001_50    41.890000
# m                2.550000
# Name: UnitPrice, Length: 4070, dtype: float64

# %% [markdown]
# ## 5. Faça dois gráficos de barras, sendo um da quantidade de compras e outro do total de faturamento por país.
# Essa lista não possui correção automática.

# %%
# Resposta da 5.
def plot_bar_graph(data,title,ylabel):
  plt.figure(figsize =(11, 6))
  plt.bar(data.index, data.values, color = 'orange')
  plt.ylabel(ylabel)
  plt.xlabel("# Países")
  plt.title(title)
  plt.xticks(rotation='vertical')
  plt.yscale('log')
  plt.show()

quantity_sum_df_grouped_by_country = df.groupby("Country")['Quantity'].sum()  
total_values_sum_df_grouped_by_country = df_with_total_values.groupby("Country")["TotalValues"].sum()

# Quantidades
plot_bar_graph(quantity_sum_df_grouped_by_country,"Quantidade de compras por país","# Quantidade de compras")


# Total de faturatamento
plot_bar_graph(total_values_sum_df_grouped_by_country,"Total de faturamento por país","# Total de faturamento")

# %% [markdown]
# ## 6. Considerando os 100 produtos mais vendidos, é possível visualizar alguma diferença entre a distribuição dos preços unitários desses produtos ao se comparar os países “Australia” e “United Kingdom”? Faça um ou mais gráficos para ajudar a responder.
# Essa lista não possui correção automática.

# %%
# Resposta da 6.
def unit_prices_in_best_products_by_country(country):
  index_best_hundred_procucts_sellers = df.groupby(['StockCode'])['Quantity'].sum().sort_values(ascending=False)[:100].index
  return df[ (df['StockCode'].isin(index_best_hundred_procucts_sellers)) & (df['Country']==country)]['UnitPrice']

fig_dims = (11, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.histplot(unit_prices_in_best_products_by_country('United Kingdom'),kde=True,color = "orange", ax=ax)
sns.histplot(unit_prices_in_best_products_by_country('Australia'),kde=True, color="red",ax=ax)
fig.legend(bbox_to_anchor=(0.85, 0.52),loc='upper right',title="Países",labels=['United Kingdom','Australia'])
plt.show()

# %% [markdown]
# ## 7. Faça um gráfico de barras, de linhas, histograma e boxplot usando a biblioteca `seaborn`.
# Essa lista não possui correção automática.
#
# A biblioteca já está importada pelo nome de `sns`. Vai um gráfico de exemplo abaixo ;)

# %%
country_group_sum = df.groupby('Country').sum().reset_index()
plt.figure(figsize=(10,10))

g=sns.barplot(data=country_group_sum, y='Country', x='Quantity', orient='h')
g.set_xscale('log')

plt.show()

# %%
# Faça outro gráfico de barras com o Seaborn aqui

# quantidade total vendida de cada um dos 10 primeiros produtos que aparecem no Dataframe

plt.figure(figsize=(11,8))
graph = sns.barplot(x=ten_first_produts.index,y=ten_first_produts.values)
graph.set_xticklabels(ten_first_produts.index,rotation = 30)

plt.show()

# %%
# Faça outro gráfico de linhas com o Seaborn aqui

# Faturamento (total de preços das vendas) por dia.

plt.figure(figsize=(11,8))
sns.lineplot(data = total_values_per_day, color = "orange")
plt.show()

# %%
# Faça outro gráfico de histograma com o Seaborn aqui

# Faturamento (total de preços das vendas) por dia.

plt.figure(figsize=(11,8))
graph = sns.histplot(total_values_per_day,color = "orange")
graph.set_xscale('log')
plt.show()

# %%
# Faça outro gráfico de boxplot com o Seaborn aqui

# Preços unitários dos produtos. Considere somente os 10 produtos mais vendidos.

plt.figure(figsize=(11,8))
sns.boxplot(best_selling_products_unit_prices,color = "orange")
plt.show()

# %% [markdown]
# ## 7. Faça uma breve análise e comparação dos plots feitos com o `seaborn` e com o `matplotlib`.
# Qual você gostou mais? Viu alguma diferença em performance neles?

# %% [markdown]
# Resposta da 7.:
#
# O seaborn possui divermos temas e gráficos em comparação ao matplotlib que tem maior facilidade pensando em implementação e menor curva de aprendizagem, já que tem funcionalidades mais básicas. Além disso, a sintaxe entre os dois é bem distinta. Foi percecptível nas últimas questões que o seaborn tem uma performance relativamente pior comparado ao matplotlib.
